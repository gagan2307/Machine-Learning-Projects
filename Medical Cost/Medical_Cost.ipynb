# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset_.csv")

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region  medical charges
# 0   19  female  27.900         0    yes  southwest      16884.92400
# 1   18    male  33.770         1     no  southeast       1725.55230
# 2   28    male  33.000         3     no  southeast       4449.46200
# 3   33    male  22.705         0     no  northwest      21984.47061
# 4   32    male  28.880         0     no  northwest       3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              1338 non-null   int64
#  1   sex              1338 non-null   object
#  2   bmi              1338 non-null   float64
#  3   children         1338 non-null   int64
#  4   smoker           1338 non-null   object
#  5   region           1338 non-null   object
#  6   medical charges  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children  medical charges
# count  1338.000000  1338.000000  1338.000000      1338.000000
# mean     39.207025    30.663397     1.094918     13270.422265
# std      14.049960     6.098187     1.205493     12110.011237
# min      18.000000    15.960000     0.000000      1121.873900
# 25%      27.000000    26.296250     0.000000      4740.287150
# 50%      39.000000    30.400000     1.000000      9382.033000
# 75%      51.000000    34.693750     2.000000     16639.912515
# max      64.000000    53.130000     5.000000     63770.428010

# %%
df.isnull().sum()
# Out:
# age                0
# sex                0
# bmi                0
# children           0
# smoker             0
# region             0
# medical charges    0
# dtype: int64

# %% [markdown]
# # Age
#
# *Conclusion*
# 1. Mostply Population Density is between ages 20 and 40
# 2. As the age increases the mean medical charges also increases

# %%
df['age'].value_counts().plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot(by = 'age', column=['medical charges'], grid = True, figsize =(10,8))
# Out:
# <Axes: title={'center': 'medical charges'}, xlabel='age'>

# %%
plt.subplots(figsize = (10, 8))
plt.scatter(df['age'], df['medical charges'])
plt.xlabel('age')
plt.ylabel('medical charges')
plt.show()

# %% [markdown]
# # Sex
#
# *Conclusion*
# 1. Males and females are almost same
# 2. No Null values

# %%
df['sex'].describe()
# Out:
# count     1338
# unique       2
# top       male
# freq       676
# Name: sex, dtype: object

# %%
df['sex'].value_counts()
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %%
df['sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='sex'>

# %%
df.boxplot(by = 'sex', column=['medical charges'], grid = True)
# Out:
# <Axes: title={'center': 'medical charges'}, xlabel='sex'>

# %%
sex_dict = {"male" : 1, "female": 0}
df['sex'].replace(sex_dict)
df.head()
# Out:
#    age  sex     bmi  children  smoker  region  medical charges
# 0   19    0  27.900         0       1       1      16884.92400
# 1   18    1  33.770         1       0       3       1725.55230
# 2   28    1  33.000         3       0       3       4449.46200
# 3   33    1  22.705         0       0       2      21984.47061
# 4   32    1  28.880         0       0       2       3866.85520

# %% [markdown]
# # BMI
# *Conclusion*
# 1. Most people with low BMI tends to pay lay
# 2. It is almost perfectly Normally distributed

# %%
df['bmi'].describe()
# Out:
# count    1338.000000
# mean       30.663397
# std         6.098187
# min        15.960000
# 25%        26.296250
# 50%        30.400000
# 75%        34.693750
# max        53.130000
# Name: bmi, dtype: float64

# %%
df['bmi'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['bmi'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
plt.subplots(figsize = (10, 8))
plt.scatter(df['bmi'], df['medical charges'])
plt.xlabel('bmi')
plt.ylabel('medical charges')
plt.show()

# %% [markdown]
# # Children
# *Conclusion*

# %%
df['children'].describe()
# Out:
# count    1338.000000
# mean        1.094918
# std         1.205493
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max         5.000000
# Name: children, dtype: float64

# %%
df['children'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='children'>

# %%
df.boxplot(by = 'children', column=['medical charges'], grid = True)
# Out:
# <Axes: title={'center': 'medical charges'}, xlabel='children'>

# %% [markdown]
# # Smoker
# *Conclsion*
# 1. Smoker tends to pay higher medical charges
# 2. There are many non smokers who pay way higher as compared to other non smokers

# %%
smoker_dict = {"yes" : 1, "no": 0}
df['smoker'].replace(smoker_dict)
df.head()
# Out:
#    age     sex     bmi  children  smoker  region  medical charges
# 0   19  female  27.900         0       1       1      16884.92400
# 1   18    male  33.770         1       0       3       1725.55230
# 2   28    male  33.000         3       0       3       4449.46200
# 3   33    male  22.705         0       0       2      21984.47061
# 4   32    male  28.880         0       0       2       3866.85520

# %%
plt.subplots(figsize = (10, 8))
plt.scatter(df['smoker'], df['medical charges'])
plt.xlabel('smoker')
plt.ylabel('medical charges')
plt.show()

# %%
df.boxplot(by = 'smoker', column=['medical charges'], grid = True)
# Out:
# <Axes: title={'center': 'medical charges'}, xlabel='smoker'>

# %% [markdown]
# # Region
# *Conclusion*

# %%
df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
df['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
df.boxplot(by = 'region', column=['medical charges'], grid = True)
# Out:
# <Axes: title={'center': 'medical charges'}, xlabel='region'>

# %%
plt.subplots(figsize = (10, 8))
plt.scatter(df['region'], df['medical charges'])
plt.xlabel('region')
plt.ylabel('medical charges')
plt.show()

# %%
region_dict = {"southwest":1,"northwest":2,"southeast":3,"northeast":4}
df['region'].replace(region_dict,)
df.head()
# Out:
#    age     sex     bmi  children  smoker  region  medical charges
# 0   19  female  27.900         0       1       1      16884.92400
# 1   18    male  33.770         1       0       3       1725.55230
# 2   28    male  33.000         3       0       3       4449.46200
# 3   33    male  22.705         0       0       2      21984.47061
# 4   32    male  28.880         0       0       2       3866.85520

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
from sklearn.linear_model import (
    LinearRegression, 
    Ridge, 
    Lasso, 
    ElasticNet, 
    BayesianRidge, 
    LassoLars, 
    OrthogonalMatchingPursuit, 
    SGDRegressor, 
    PassiveAggressiveRegressor
)
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import (
    RandomForestRegressor, 
    AdaBoostRegressor, 
    GradientBoostingRegressor, 
    BaggingRegressor, 
    ExtraTreesRegressor
)

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
regressors = {
    "LinearRegression": LinearRegression(),
    "Ridge": Ridge(),
    "Lasso": Lasso(),
    "ElasticNet": ElasticNet(),
    "BayesianRidge": BayesianRidge(),
    "LassoLars": LassoLars(),
    "OrthogonalMatchingPursuit": OrthogonalMatchingPursuit(),
    "SGDRegressor": SGDRegressor(),
    "PassiveAggressiveRegressor": PassiveAggressiveRegressor(),
    "DecisionTreeRegressor": DecisionTreeRegressor(),
    "RandomForestRegressor": RandomForestRegressor(),
    "AdaBoostRegressor": AdaBoostRegressor(),
    "GradientBoostingRegressor": GradientBoostingRegressor(),
    "BaggingRegressor": BaggingRegressor(),
    "ExtraTreesRegressor": ExtraTreesRegressor()
}

# %%
best_model_name = None
best_model = None
best_mse = float('inf')
best_r2 = float('-inf')
for name, model in regressors.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    print(f"{name} Mean Squared Error: {mse}, R² Score: {r2}")
    
    
    if mse < best_mse and r2 > best_r2:
        best_mse = mse
        best_r2 = r2
        best_model_name = name
        best_model = model

print(f"\nBest Model: {best_model_name} with MSE: {best_mse} and R² Score: {best_r2}")
# Out:
# LinearRegression Mean Squared Error: 35282943.23777604, R² Score: 0.7592341868881927
# Ridge Mean Squared Error: 35301111.164783925, R² Score: 0.7591102115245408
# Lasso Mean Squared Error: 35282471.95301699, R² Score: 0.7592374028687149
# ElasticNet Mean Squared Error: 86788324.34060614, R² Score: 0.40776875280333336
# BayesianRidge Mean Squared Error: 35289355.42569205, R² Score: 0.7591904310249977
# LassoLars Mean Squared Error: 35282471.988329135, R² Score: 0.7592374026277499
# OrthogonalMatchingPursuit Mean Squared Error: 131694016.35773064, R² Score: 0.10133866336919395
# SGDRegressor Mean Squared Error: 2.7807589454717895e+19, R² Score: -189755056447.2466
# PassiveAggressiveRegressor Mean Squared Error: 68336380.16307746, R² Score: 0.5336822094403597
# DecisionTreeRegressor Mean Squared Error: 42972956.10420018, R² Score: 0.7067586270079571
# RandomForestRegressor Mean Squared Error: 23211720.486266907, R² Score: 0.8416065032064397
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# Example model
model = GradientBoostingRegressor()

# Perform 5-fold cross-validation
cv_scores = cross_val_score(model, X, y, cv=5, scoring='r2')

print(f"Cross-validated R² scores: {cv_scores}")
print(f"Mean R² score: {cv_scores.mean()}")

# Train-test split performance comparison
model.fit(X_train, y_train)
train_r2 = model.score(X_train, y_train)
test_r2 = model.score(X_test, y_test)

print(f"Training R² score: {train_r2}")
print(f"Test R² score: {test_r2}")
# Out:
# Cross-validated R² scores: [0.87135799 0.8005173  0.89162924 0.84757926 0.85952478]
# Mean R² score: 0.8541217160689282
# Training R² score: 0.909386608412492
# Test R² score: 0.8584155608976582

# %%
y_best_pred = best_model.predict(X_test)
print(f"\nPredictions with {best_model_name}: {y_best_pred}")
# Out:
# Predictions with GradientBoostingRegressor: [ 9846.40516576  5715.05901609 28980.56419266  8909.59032591
#  34267.46316215  5050.94783037  2212.56725858 15093.79468989
#   4519.8304957  10936.14173376 18722.92631947  7521.44202295
#   5765.88124277 46024.39172855 47113.64964384 45669.84726657
#  11594.3980484  46905.23943851  8645.71834092 24890.68981957
#   5224.31163218  9071.74927975  1437.49456844  4181.4728227
#  11515.90529215 12832.53455683 14667.48631938  6163.21414486
#  11467.41153011  5881.64243858  8035.77796233 11983.39086587
#   3279.64535227  5413.88196181  4057.70607761  9690.86924834
#   4133.34880398  8258.96414025 26627.43950388 40400.65278854
#  11308.32630556  4336.41715746 14135.24761899 14246.40973649
#   7604.88152901 16501.2965148   6026.34306177  5774.63361406
#  43497.43149636  6350.75765882 14711.46753404  2785.54010779
#   6677.94191029  2593.36241396 12174.7912035  11944.01762325
#   4746.88291704 40181.77081091 12300.56142262 12689.25238174
# ...

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region  medical charges
# 0      19    0  27.900         0       1       1      16884.92400
# 1      18    1  33.770         1       0       3       1725.55230
# 2      28    1  33.000         3       0       3       4449.46200
# 3      33    1  22.705         0       0       2      21984.47061
# 4      32    1  28.880         0       0       2       3866.85520
# ...   ...  ...     ...       ...     ...     ...              ...
# 1333   50    1  30.970         3       0       2      10600.54830
# 1334   18    0  31.920         0       0       4       2205.98080
# 1335   18    0  36.850         0       0       3       1629.83350
# 1336   21    0  25.800         0       0       1       2007.94500
# 1337   61    0  29.070         0       1       2      29141.36030
#
# [1338 rows x 7 columns]

# %%
input_data2 = np.array([[19,0,27.900,0,1,1]])
prediction2 = best_model.predict(input_data2)
print(prediction2)
# Out:
# [17919.95231763]
# C:\Users\SANDHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(

# %%
input_data = np.array([[61,0,29.070,0,1,2]])
prediction = best_model.predict(input_data)
print(prediction)
# Out:
# [28765.52452947]
# C:\Users\SANDHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
